# %% [markdown]
# ### Practice zipping a small # of latitudes & longitudes & then unpacking zipped tuple to see how the packing/unpacking work

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %% [markdown]
# Next, let's unpack our lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. In a new cell in the WeatherPy.ipynb file, add the following code and run the cell.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### 6.1.5 Generate Random World Cities

# %%
#pip install citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

#coordinates_list = list(coordinates)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# almaznyy ru
# yerbogachen ru
# port keats au
# aykhal ru
# atuona pf
# rikitea pf
# west wendover us
# nikolskoye ru
# arraial do cabo br
# butaritari ki
# pedro carbo ec
# illoqqortoormiut gl
# saleaula ws
# georgetown sh
# mataura pf
# rikitea pf
# deniliquin au
# norman wells ca
# grand river south east mu
# rikitea pf
# malanje ao
# atuona pf
# busselton au
# alice springs au
# yar-sale ru
# berlevag no
# alihe cn
# khislavichi ru
# port elizabeth za
# port alfred za
# mehamn no
# fukue jp
# pevek ru
# bluff nz
# songea tz
# kiyasovo ru
# mapastepec mx
# ratnagiri in
# ngukurr au
# san patricio mx
# belushya guba ru
# butaritari ki
# rikitea pf
# bakchar ru
# cururupu br
# tiarei pf
# port-gentil ga
# carnarvon au
# kapaa us
# oranjemund na
# vaini to
# torbay ca
# rikitea pf
# vaitupu wf
# buala sb
# tuatapere nz
# okha ru
# nikolskoye ru
# sosnovo-ozerskoye ru
# hasaki jp
# karratha au
# vaini to
# hermanus za
# chokurdakh ru
# butaritari ki
# bethel us
# hilo us
# tibati cm
# barentsburg sj
# hasaki jp
# bluff nz
# hilo us
# mataura pf
# gazanjyk tm
# tuktoyaktuk ca
# mugumu tz
# hermanus za
# katsuura jp
# laguna br
# arman ru
# sinop tr
# kapaa us
# port elizabeth za
# albany au
# teguise es
# brae gb
# attawapiskat ca
# butaritari ki
# remuna in
# mataura pf
# saint-pierre pm
# udachnyy ru
# buin pg
# haicheng cn
# dikson ru
# lebu cl
# seymchan ru
# nhulunbuy au
# ilulissat gl
# torbay ca
# pevek ru
# bluff nz
# katobu id
# cabedelo br
# atuona pf
# katsuura jp
# mataura pf
# pochutla mx
# dalby au
# lagoa pt
# yellowknife ca
# mahebourg mu
# jamestown sh
# bambous virieux mu
# ushuaia ar
# punta arenas cl
# hermanus za
# qaanaaq gl
# ushuaia ar
# illoqqortoormiut gl
# pangnirtung ca
# yellowknife ca
# busselton au
# iqaluit ca
# cape town za
# belushya guba ru
# victoria sc
# kapaa us
# sunagawa jp
# provideniya ru
# mataura pf
# albany au
# busselton au
# atuona pf
# cape town za
# central point us
# asfi ma
# upata ve
# rikitea pf
# bathsheba bb
# shaunavon ca
# pedregal pa
# arraial do cabo br
# ambilobe mg
# illoqqortoormiut gl
# avarua ck
# monrovia lr
# highland springs us
# stantsionno-oyashinskiy ru
# nipawin ca
# new norfolk au
# campo verde br
# victoria sc
# port elizabeth za
# tura ru
# albany au
# royan fr
# qaanaaq gl
# codrington ag
# hermanus za
# kongolo cd
# dingle ie
# east london za
# yellowknife ca
# san cristobal ec
# atuona pf
# busselton au
# constitucion mx
# whitehorse ca
# mataura pf
# haapiti pf
# shelburne ca
# belushya guba ru
# mataura pf
# codrington ag
# mount gambier au
# thinadhoo mv
# strezhevoy ru
# tupik ru
# dikson ru
# namibe ao
# machali cl
# tahta eg
# barrow us
# sinop tr
# kaeo nz
# amderma ru
# rikitea pf
# mataura pf
# bobo dioulasso bf
# hailey us
# busselton au
# albany au
# marcona pe
# busselton au
# taolanaro mg
# nerchinskiy zavod ru
# provideniya ru
# fortuna us
# miramar mx
# taolanaro mg
# albany au
# belyy yar ru
# barrow us
# bredasdorp za
# hermanus za
# punta arenas cl
# kapaa us
# albany au
# mataura pf
# port elizabeth za
# mar del plata ar
# la ronge ca
# castlegar ca
# husavik is
# mataura pf
# kahului us
# nizhneyansk ru
# ponta do sol cv
# lawrenceburg us
# thompson ca
# belushya guba ru
# warqla dz
# saskylakh ru
# bafq ir
# cidreira br
# dubbo au
# taolanaro mg
# mahebourg mu
# saint-leu re
# hobart au
# provideniya ru
# mataura pf
# pisco pe
# vestmanna fo
# tenenkou ml
# kitimat ca
# bluff nz
# udachnyy ru
# barrow us
# ribeira grande pt
# busselton au
# rikitea pf
# daliang cn
# margate za
# rikitea pf
# kodiak us
# ola ru
# darya khan pk
# lebu cl
# bonthe sl
# hata in
# san pancrazio salentino it
# tuktoyaktuk ca
# ukiah us
# jamestown sh
# vardo no
# bredasdorp za
# husavik is
# dikson ru
# rikitea pf
# poum nc
# lodja cd
# coahuayana mx
# mount gambier au
# talnakh ru
# tomigusuku jp
# rosarito mx
# lagoa pt
# cap malheureux mu
# kuryk kz
# illoqqortoormiut gl
# tsihombe mg
# yavatmal in
# illoqqortoormiut gl
# ushuaia ar
# vicente guerrero mx
# gorontalo id
# acajutla sv
# kamskoye ustye ru
# verkhnetulomskiy ru
# jamestown sh
# hilo us
# punta arenas cl
# san juan de uraba co
# bemidji us
# busselton au
# ancud cl
# luderitz na
# albany au
# ushuaia ar
# albany au
# anloga gh
# rikitea pf
# seminole us
# vaini to
# tilichiki ru
# lubango ao
# punta gorda bz
# cape town za
# butaritari ki
# grand river south east mu
# albany au
# hit iq
# kodiak us
# ust-nera ru
# vaini to
# barrow us
# bo no
# nishihara jp
# butaritari ki
# inta ru
# onega ru
# khatanga ru
# thompson ca
# paamiut gl
# airai pw
# victoria sc
# lasa cn
# busselton au
# dagda lv
# klaksvik fo
# busselton au
# trairi br
# ushuaia ar
# cape town za
# meulaboh id
# bluff nz
# rikitea pf
# sao filipe cv
# peniche pt
# taolanaro mg
# makushino ru
# marrakesh ma
# civitavecchia it
# khatanga ru
# klaksvik fo
# tiksi ru
# kapaa us
# iqaluit ca
# atuona pf
# fortuna us
# vaini to
# nanded in
# rikitea pf
# jacona mx
# amahai id
# nizhneyansk ru
# airai pw
# punta arenas cl
# norman wells ca
# kodiak us
# busselton au
# bredasdorp za
# tautira pf
# suna ru
# avarua ck
# ambilobe mg
# hobart au
# north bend us
# attawapiskat ca
# mataura pf
# rikitea pf
# gamba ga
# yellowknife ca
# dunedin nz
# tumannyy ru
# the valley ai
# dingle ie
# saskylakh ru
# shache cn
# busselton au
# kavieng pg
# college us
# taungdwingyi mm
# attawapiskat ca
# dikson ru
# cherskiy ru
# bengkulu id
# dikson ru
# ajdabiya ly
# khatanga ru
# provideniya ru
# kavieng pg
# jamestown sh
# udachnyy ru
# grand river south east mu
# takhtamygda ru
# rikitea pf
# kapaa us
# mataura pf
# ilulissat gl
# bluff nz
# grand centre ca
# mataura pf
# punta arenas cl
# raga sd
# ikot ekpene ng
# kavaratti in
# punta arenas cl
# kamenskoye ru
# hilo us
# upernavik gl
# shaoyang cn
# pangnirtung ca
# barabai id
# esperance au
# nizhneyansk ru
# sobolevo ru
# bonthe sl
# kenora ca
# longyearbyen sj
# nguiu au
# beringovskiy ru
# tsihombe mg
# bluff nz
# rikitea pf
# palmer us
# richards bay za
# souillac mu
# punta arenas cl
# bluff nz
# avarua ck
# ilebo cd
# saint george bm
# carnarvon au
# elko us
# la ronge ca
# bandarbeyla so
# diego de almagro cl
# thompson ca
# ushuaia ar
# upernavik gl
# provideniya ru
# talaya ru
# hermanus za
# buraydah sa
# hasaki jp
# punta arenas cl
# neiafu to
# bluff nz
# ust-ilimsk ru
# avarua ck
# huarmey pe
# vestmanna fo
# rikitea pf
# rikitea pf
# torbay ca
# mount isa au
# thompson ca
# victoria sc
# kiama au
# jamestown sh
# katangli ru
# alofi nu
# bambous virieux mu
# aquiraz br
# guamo co
# cockburn harbour tc
# mataura pf
# talara pe
# wasilla us
# rikitea pf
# ushuaia ar
# nagato jp
# puerto ayora ec
# kultuk ru
# rikitea pf
# carnarvon au
# kargil in
# alofi nu
# taolanaro mg
# ancud cl
# rudnichnyy ru
# saint george bm
# moramanga mg
# batagay-alyta ru
# kaitangata nz
# saint-philippe re
# gloversville us
# nikolskoye ru
# kamenskoye ru
# atuona pf
# avarua ck
# nikolskoye ru
# ilulissat gl
# viedma ar
# mount isa au
# provideniya ru
# boende cd
# bulalacao ph
# port alfred za
# tres arroyos ar
# jamestown sh
# shymkent kz
# los llanos de aridane es
# oranjemund na
# amderma ru
# sur om
# airai pw
# chuy uy
# albany au
# victoria sc
# ponta delgada pt
# attawapiskat ca
# clyde river ca
# taolanaro mg
# ushuaia ar
# ancud cl
# klaksvik fo
# mozarlandia br
# cape town za
# rikitea pf
# tulun ru
# oktyabrskoye ru
# belushya guba ru
# rikitea pf
# hithadhoo mv
# albany au
# waitati nz
# raozan bd
# kongolo cd
# rikitea pf
# hermanus za
# udachnyy ru
# pimentel pe
# rikitea pf
# hobart au
# ahipara nz
# chesapeake us
# albany au
# souillac mu
# kaitangata nz
# ancud cl
# vaini to
# bredasdorp za
# cape town za
# rikitea pf
# qaanaaq gl
# port blair in
# mahon es
# vardo no
# busselton au
# rikitea pf
# atambua id
# bluff nz
# xining cn
# qaanaaq gl
# yeppoon au
# saskylakh ru
# hermanus za
# hilo us
# aasiaat gl
# port elizabeth za
# bluff nz
# bluff nz
# rikitea pf
# hermanus za
# hobart au
# lagoa pt
# bengkulu id
# longyearbyen sj
# nizhneyansk ru
# rikitea pf
# tsihombe mg
# port alfred za
# savannakhet la
# chuy uy
# punta arenas cl
# kilindoni tz
# punta arenas cl
# kapaa us
# bluff nz
# hilo us
# san cristobal ec
# maldonado uy
# beatrice us
# ushuaia ar
# tampin my
# barrow us
# airai pw
# caravelas br
# mataura pf
# hilo us
# ponta do sol cv
# souillac mu
# barcelos br
# atuona pf
# san quintin mx
# saint-philippe re
# yima cn
# atar mr
# georgetown sh
# ushuaia ar
# barrow us
# upernavik gl
# flinders au
# termiz uz
# pekalongan id
# can tho vn
# umzimvubu za
# santos dumont br
# yellowknife ca
# pemberton ca
# nikolskoye ru
# albany au
# punta arenas cl
# mocambique mz
# bolshoye ignatovo ru
# ukiah us
# juegang cn
# mataura pf
# vila vu
# narsaq gl
# taolanaro mg
# saint-philippe re
# pevek ru
# bafoulabe ml
# gazli uz
# taolanaro mg
# punta arenas cl
# katsuura jp
# porto velho br
# atuona pf
# manzil jamil tn
# rikitea pf
# bafq ir
# shenjiamen cn
# cherskiy ru
# kungurtug ru
# severo-kurilsk ru
# lasa cn
# izhma ru
# san cristobal ec
# severo-kurilsk ru
# stromness gb
# nohar in
# kupang id
# dahra sn
# cidreira br
# longyearbyen sj
# hermanus za
# sar-e pul af
# cape town za
# indian head ca
# lavrentiya ru
# albany au
# grand river south east mu
# bredasdorp za
# saint anthony ca
# hobart au
# meulaboh id
# manjakandriana mg
# dunedin nz
# vaini to
# san angelo us
# broken hill au
# yar-sale ru
# vardo no
# east london za
# qaanaaq gl
# cape town za
# punta arenas cl
# rikitea pf
# bam ir
# barrow us
# lagoa pt
# arraial do cabo br
# plettenberg bay za
# sistranda no
# luderitz na
# alofi nu
# kaitangata nz
# amderma ru
# portland au
# belaya gora ru
# toora-khem ru
# busselton au
# rikitea pf
# kosh-agach ru
# morant bay jm
# samusu ws
# mataura pf
# yulara au
# narrabri au
# puerto ayora ec
# rikitea pf
# bethel us
# hermanus za
# berlevag no
# sisophon kh
# port alfred za
# busselton au
# igrim ru
# ville-marie ca
# mataura pf
# jalu ly
# rikitea pf
# hobart au
# luderitz na
# tuatapere nz
# mamontovo ru
# lompoc us
# taolanaro mg
# albany au
# kastamonu tr
# upernavik gl
# grindavik is
# mataura pf
# halifax ca
# taolanaro mg
# adrar dz
# kapaa us
# barentsburg sj
# dikson ru
# tidore id
# havre-saint-pierre ca
# east london za
# portland au
# callaway us
# kahului us
# emba kz
# half moon bay us
# bluff nz
# olafsvik is
# avera pf
# vaini to
# lakes entrance au
# buenos aires cr
# barrow us
# tatarskaya kargala ru
# tiarei pf
# georgetown sh
# matara lk
# cherskiy ru
# busselton au
# castro cl
# saldanha za
# mar del plata ar
# avarua ck
# aurillac fr
# moose factory ca
# yerbogachen ru
# skelleftea se
# khatanga ru
# saskylakh ru
# nizhneyansk ru
# camabatela ao
# punta arenas cl
# punta arenas cl
# phalombe mw
# havre us
# sicamous ca
# klyuchi ru
# shaowu cn
# port elizabeth za
# dzhusaly kz
# butaritari ki
# okhotsk ru
# quatre cocos mu
# saint-philippe re
# busselton au
# hasaki jp
# kaitangata nz
# qaanaaq gl
# east london za
# klaksvik fo
# tura ru
# maldonado uy
# kapaa us
# kapaa us
# lebu cl
# mount gambier au
# mahebourg mu
# mataura pf
# atuona pf
# the valley ai
# taolanaro mg
# hermanus za
# qaanaaq gl
# skibbereen ie
# vao nc
# yellowknife ca
# taolanaro mg
# ponta do sol cv
# karangampel id
# talnakh ru
# bambous virieux mu
# madona lv
# umzimvubu za
# anadyr ru
# nizhniy tsasuchey ru
# qaanaaq gl
# ushuaia ar
# lompoc us
# guerrero negro mx
# mahebourg mu
# ushuaia ar
# haines junction ca
# hobart au
# monjaras hn
# hilo us
# vaini to
# atuona pf
# jamestown sh
# port alfred za
# umzimvubu za
# port elizabeth za
# jeremoabo br
# busselton au
# rikitea pf
# mataura pf
# namtsy ru
# hualmay pe
# busselton au
# georgetown sh
# tasiilaq gl
# mataura pf
# carnarvon au
# punta arenas cl
# ixtapa mx
# jizan sa
# talnakh ru
# tuatapere nz
# sentyabrskiy ru
# sandy bay hn
# palauig ph
# karatau kz
# rikitea pf
# kapaa us
# port elizabeth za
# hobart au
# kismayo so
# illoqqortoormiut gl
# port hardy ca
# hilo us
# marsa matruh eg
# illoqqortoormiut gl
# bluff nz
# severo-kurilsk ru
# ushuaia ar
# barentsburg sj
# sao joao da barra br
# lodja cd
# grand river south east mu
# pisco pe
# new norfolk au
# tasiilaq gl
# faya td
# chokurdakh ru
# port alfred za
# alofi nu
# alausi ec
# vaini to
# erzin ru
# georgetown sh
# beringovskiy ru
# albany au
# butaritari ki
# iqaluit ca
# punta arenas cl
# gamba ga
# bhavnagar in
# bethel us
# adrar dz
# vila do maio cv
# carutapera br
# cape town za
# illoqqortoormiut gl
# mweka cd
# torbay ca
# faanui pf
# ushuaia ar
# hermanus za
# itarema br
# bluff nz
# ilulissat gl
# tame co
# buin pg
# shimoda jp
# marcona pe
# kaitangata nz
# ilebo cd
# sambava mg
# phan rang vn
# chuy uy
# vaini to
# udachnyy ru
# hermanus za
# zinder ne
# ixtapa mx
# guerrero negro mx
# taolanaro mg
# liku wf
# talnakh ru
# yellowknife ca
# kizner ru
# pangnirtung ca
# yarada in
# tomatlan mx
# yima cn
# alofi nu
# beringovskiy ru
# bandar-e lengeh ir
# puerto ayora ec
# hobart au
# micheweni tz
# vaini to
# ushuaia ar
# jamestown sh
# barentsburg sj
# busselton au
# iqaluit ca
# saskylakh ru
# nabari jp
# illoqqortoormiut gl
# severo-kurilsk ru
# aden ye
# porto torres it
# khatanga ru
# puerto ayora ec
# port alfred za
# castlerea ie
# severo-kurilsk ru
# vaini to
# tiarei pf
# saint-augustin ca
# tuktoyaktuk ca
# vaini to
# kodiak us
# alofi nu
# sanmenxia cn
# half moon bay us
# saryshagan kz
# waingapu id
# vaini to
# vila franca do campo pt
# basco ph
# bethel us
# sola vu
# takoradi gh
# rikitea pf
# nikolskoye ru
# puerto ayora ec
# bilibino ru
# severo-kurilsk ru
# skrunda lv
# georgetown sh
# new norfolk au
# tiksi ru
# bredasdorp za
# hermanus za
# castro cl
# vaitupu wf
# airai pw
# mumford gh
# sao joao da barra br
# busselton au
# georgetown sh
# ushuaia ar
# cabo san lucas mx
# mataura pf
# cape town za
# uusikaupunki fi
# neuquen ar
# bengkulu id
# roald no
# vavoua ci
# balkhash kz
# jamestown sh
# montes claros br
# muisne ec
# mataura pf
# lossiemouth gb
# castro cl
# henties bay na
# aklavik ca
# sentyabrskiy ru
# jibuti dj
# east london za
# saint-philippe re
# lebu cl
# san ramon de la nueva oran ar
# nikolskoye ru
# ushuaia ar
# hasaki jp
# hermanus za
# jamestown sh
# kapaa us
# port elizabeth za
# punta arenas cl
# lavrentiya ru
# ribeira grande pt
# susaki jp
# mbaiki cf
# san patricio mx
# ilulissat gl
# buraydah sa
# sao filipe cv
# jamestown sh
# terrace bay ca
# toliary mg
# lazaro cardenas mx
# busselton au
# salta ar
# bundaberg au
# ushuaia ar
# talnakh ru
# niamey ne
# barentsburg sj
# kaitangata nz
# horadiz az
# castro cl
# alofi nu
# tuktoyaktuk ca
# port macquarie au
# tuktoyaktuk ca
# tuatapere nz
# port elizabeth za
# arraial do cabo br
# barabash ru
# nizhneyansk ru
# hermanus za
# butaritari ki
# yellowknife ca
# buraydah sa
# upernavik gl
# ponta do sol cv
# yerbogachen ru
# sentyabrskiy ru
# mar del plata ar
# baijiantan cn
# tuktoyaktuk ca
# torbay ca
# mogadishu so
# madras in
# cherskiy ru
# illoqqortoormiut gl
# gushikawa jp
# punta arenas cl
# kruisfontein za
# avarua ck
# rikitea pf
# lompoc us
# ust-maya ru
# caravelas br
# sabang id
# mataura pf
# fare pf
# ushuaia ar
# busselton au
# carnarvon au
# hithadhoo mv
# mataura pf
# cheney us
# thompson ca
# mataura pf
# hilo us
# brzeg dolny pl
# yazykovo ru
# siuna ni
# albany au
# grand river south east mu
# punta arenas cl
# arraial do cabo br
# north platte us
# mar del plata ar
# nichinan jp
# barrow us
# nhulunbuy au
# yatou cn
# dikson ru
# mar del plata ar
# rocha uy
# ondangwa na
# barentsburg sj
# souillac mu
# toora-khem ru
# hamilton bm
# ushuaia ar
# ushuaia ar
# margate za
# ushuaia ar
# hobart au
# melfi td
# san patricio mx
# daru pg
# padang id
# vila franca do campo pt
# rikitea pf
# skibbereen ie
# broken hill au
# puerto ayora ec
# kahului us
# kodiak us
# touros br
# santa eulalia del rio es
# hobart au
# east london za
# progreso mx
# hobart au
# okha ru
# saldanha za
# jamestown sh
# atuona pf
# saint george bm
# altay cn
# hermanus za
# chuy uy
# rikitea pf
# narasannapeta in
# samalaeulu ws
# sovetskiy ru
# barrow us
# amudat ug
# lixourion gr
# port-gentil ga
# khatanga ru
# shakhtinsk kz
# kendari id
# makakilo city us
# havre-saint-pierre ca
# constitucion cl
# jamestown sh
# cape town za
# mumford gh
# madimba tz
# puerto colombia co
# mataura pf
# kruisfontein za
# mataura pf
# barrow us
# mar del plata ar
# airai pw
# airai pw
# yurginskoye ru
# alofi nu
# xian cn
# pevek ru
# yantal ru
# east london za
# busselton au
# punta arenas cl
# tuktoyaktuk ca
# saint-philippe re
# provins fr
# beringovskiy ru
# atuona pf
# rikitea pf
# east london za
# petropavlovsk-kamchatskiy ru
# ushuaia ar
# samusu ws
# hermanus za
# vaitupu wf
# busselton au
# taolanaro mg
# bengkulu id
# mahebourg mu
# hermanus za
# mizdah ly
# eydhafushi mv
# east london za
# ponta do sol cv
# kapaa us
# norman wells ca
# punta arenas cl
# east london za
# hobart au
# fortuna us
# hermanus za
# san patricio mx
# alotau pg
# vaini to
# qaanaaq gl
# hailey us
# umm kaddadah sd
# charters towers au
# belluru in
# busselton au
# vaini to
# cabedelo br
# pascagoula us
# samarai pg
# jamestown sh
# hermanus za
# maiduguri ng
# punta arenas cl
# tasiilaq gl
# grindavik is
# busselton au
# busselton au
# puerto maldonado pe
# klaksvik fo
# havoysund no
# iralaya hn
# yaan cn
# irituia br
# port alfred za
# tuktoyaktuk ca
# hithadhoo mv
# khatanga ru
# soe id
# omboue ga
# lompoc us
# mataura pf
# marawi sd
# tuatapere nz
# shellbrook ca
# chokurdakh ru
# buenos aires cr
# yellowknife ca
# epe ng
# nizhneyansk ru
# butaritari ki
# romny ru
# vostok ru
# ushuaia ar
# bluff nz
# axim gh
# sentyabrskiy ru
# ocos gt
# markova ru
# vaini to
# agadir ma
# hilo us
# amderma ru
# avarua ck
# hermanus za
# college us
# yellowknife ca
# katsuura jp
# gemena cd
# atambua id
# buarcos pt
# hobart au
# port alfred za
# ushuaia ar
# rikitea pf
# rikitea pf
# aklavik ca
# westport nz
# arraial do cabo br
# chokurdakh ru
# albany au
# hilo us
# cape town za
# hermanus za
# pangnirtung ca
# nyurba ru
# atuona pf
# deyang cn
# new norfolk au
# nizhneyansk ru
# tsihombe mg
# butaritari ki
# port alfred za
# san patricio mx
# masallatah ly
# tiksi ru
# fortuna us
# rikitea pf
# domoni km
# kotelnich ru
# stephenville ca
# new norfolk au
# keti bandar pk
# hermanus za
# slave lake ca
# hermanus za
# am timan td
# mapiripan co
# rikitea pf
# barrow us
# guerrero negro mx
# borgarnes is
# victoria sc
# sataua ws
# hurghada eg
# faanui pf
# vaini to
# jamestown sh
# ribeira grande pt
# airai pw
# punta arenas cl
# east london za
# busselton au
# rikitea pf
# inuvik ca
# nikolskoye ru
# yellowknife ca
# chulman ru
# rikitea pf
# hilo us
# impfondo cg
# albany au
# saskylakh ru
# port alfred za
# bethel us
# zaoyang cn
# gorontalo id
# vaini to
# ancud cl
# punta arenas cl
# albany au
# khatanga ru
# ushuaia ar
# mar del plata ar
# vilaka lv
# bluff nz
# ushuaia ar
# punta arenas cl
# sorong id
# slave lake ca
# temaraia ki
# illoqqortoormiut gl
# hosangadi in
# sao joao da barra br
# castro cl
# abonnema ng
# san quintin mx
# bredasdorp za
# yellowknife ca
# hermanus za
# zasheyek ru
# san cristobal ec
# mitu co
# vila franca do campo pt
# ushuaia ar
# atambua id
# san isidro ph
# tuktoyaktuk ca
# port alfred za
# kapaa us
# ribeira grande pt
# guerrero negro mx
# vardo no
# kitimat ca
# nome us
# bethel us
# talnakh ru
# vaini to
# lebu cl
# klaksvik fo
# yellowknife ca
# east london za
# mataura pf
# souillac mu
# barentsburg sj
# mys shmidta ru
# loa janan id
# san juan ar
# guerrero negro mx
# mahebourg mu
# lebu cl
# evensk ru
# hithadhoo mv
# vaini to
# talnakh ru
# mataura pf
# rawson ar
# saint-philippe re
# chuy uy
# rikitea pf
# cape town za
# ribeira grande pt
# camacha pt
# toribio co
# mataura pf
# nelson bay au
# neiafu to
# tuktoyaktuk ca
# prince rupert ca
# saint-philippe re
# vostok ru
# galesong id
# buala sb
# bidar in
# kondinskoye ru
# taolanaro mg
# lebu cl
# dalbandin pk
# mpika zm
# punta arenas cl
# banda aceh id
# bluff nz
# sao jose da coroa grande br
# cockburn town tc
# bambous virieux mu
# belushya guba ru
# bredasdorp za
# yellowknife ca
# bredasdorp za
# saint-philippe re
# carnarvon au
# teofilo otoni br
# georgetown sh
# rikitea pf
# albany au
# mar del plata ar
# ballina au
# gusau ng
# pacific grove us
# inverell au
# kocser hu
# alofi nu
# imeni poliny osipenko ru
# vaini to
# upernavik gl
# taolanaro mg
# vaini to
# harper lr
# mount gambier au
# bengkulu id
# acapulco mx
# aswan eg
# jamestown sh
# kapaa us
# yellowknife ca
# georgetown sh
# thompson ca
# kyabe td
# vaini to
# sitka us
# manthani in
# bolungarvik is
# saldanha za
# cape town za
# shingu jp
# albany au
# kouango cf
# puerto ayora ec
# hermanus za
# leningradskiy ru
# ribeira grande pt
# coracora pe
# zhigansk ru
# loralai pk
# fort nelson ca
# carnarvon au
# bambous virieux mu
# hermanus za
# puerto ayora ec
# muros es
# azimur ma
# amuntai id
# marystown ca
# atuona pf
# yasothon th
# monster nl
# rikitea pf
# mys shmidta ru
# barrow us
# upernavik gl
# hilo us
# atkinson dm
# esperance au
# hamilton bm
# paamiut gl
# basco ph
# busselton au
# albany au
# junin ar
# khatanga ru
# kaitangata nz
# jamestown sh
# puerto ayora ec
# bluff nz
# ankang cn
# yellowknife ca
# ponta do sol cv
# yutsa ru
# tura ru
# nikolskoye ru
# ushuaia ar
# belushya guba ru
# yarada in
# norman wells ca
# kaitangata nz
# dikson ru
# kavaratti in
# lugovskiy ru
# mataura pf
# olinda br
# umm durman sd
# chokurdakh ru
# cape town za
# aanekoski fi
# butaritari ki
# ostrovnoy ru
# carquefou fr
# mount gambier au
# hobart au
# kapaa us
# katima mulilo na
# rikitea pf
# motala se
# ewa beach us
# iskateley ru
# portland au

# %% [markdown]
# ### 6.2.3 Make API call

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=273d1762b554f6e26bb864abe485bdc6&q=Boston

# %% [markdown]
# ### 6.2.4 Make Request for Data to an API

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# The code output will be <Response [200]>, indicating a valid response. We won't see this code when a website appears in a browser. However, when a website does not appear, we'll see a 404 code, indicating a client error.
#
# You can directly call the response code with the get() method using the status_code. If we chain the status_code to the city_weather variable, we get 200 as the output.

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather

#if city name is misspelled from Boston to Bston, get 404 response
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %% [markdown]
# When we receive a valid response from the server, we have to decide on the data format. The options are text, JSON, XML, or HTML format. We can apply the format attributes to get the data into a useful format to parse.

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":72.21,"feels_like":73.08,"temp_min":67.95,"temp_max":77.68,"pressure":1021,"humidity":84},"visibility":10000,"wind":{"speed":1.01,"deg":130,"gust":8.99},"clouds":{"all":90},"dt":1628543606,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1628502321,"sunset":1628553249},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 72.21,
#   'feels_like': 73.08,
#   'temp_min': 67.95,
#   'temp_max': 77.68,
#   'pressure': 1021,
#   'humidity': 84},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 130, 'gust': 8.99},
#  'clouds': {'all': 90},
#  'dt': 1628543606,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628502321,
#   'sunset': 1628553249},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# ### Handle Request Errors

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %% [markdown]
# When the conditional expression is evaluated, it will print City weather found if true, or City weather not found if false. When we run the cell code above, the output is City weather found.
# - If the status_code is something other than 200, JSON data will always be returned in the request. We can determine if the response was successful by checking the status_code, clicking the URL, or retrieving specific information from the JSON data.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=273d1762b554f6e26bb864abe485bdc6&q=Bston

# %% [markdown]
# ### 6.2.5 Parse a Response from an API

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 72.21,
#   'feels_like': 73.08,
#   'temp_min': 67.95,
#   'temp_max': 77.68,
#   'pressure': 1021,
#   'humidity': 84},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 130, 'gust': 8.99},
#  'clouds': {'all': 90},
#  'dt': 1628543606,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628502321,
#   'sunset': 1628553249},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# 1. First, let's get something simple, like the country code from the JSON formatted data, which is in a nested dictionary where the first dictionary starts with sys. In a new cell, let's assign a variable to the city_weather.json() data to the variable "boston_data" and run the cell.

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %% [markdown]
# 2. Next, using the sys key to get the corresponding value, we type boston_data['sys'] in a new cell and run the cell. The output is another dictionary as shown in the following image.

# %%
boston_data["sys"]
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1628502321,
#  'sunset': 1628553249}

# %% [markdown]
# 3. If we add the country key in brackets after the sys key, and run the cell again, ‘US’ will be returned in the output.

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %% [markdown]
# When we used boston_data["sys"], there was a key for sunrise and a key for sunset in the output. The value for these keys is the time of day in seconds in a database timestamp format.
# - If we want to retrieve the date in the weather data, we would add the dt key to the boston_data variable like this: boston_data["dt"].

# %%
boston_data["dt"]
# Out:
# 1628543606

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 77.68 84 90 1.01

# %% [markdown]
# ### Convert Date Timestamp

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 8, 9, 21, 13, 26)

# %% [markdown]
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime() and adding how we want the string to look inside the parentheses. In our case, we would use strftime('%Y-%m-%d %H:%M:%S').
# - Add .strftime('%Y-%m-%d %H:%M:%S') to the end of the conversion: datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S'). Rerun the cell.

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-08-09 21:13:26'

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1628545983.811818

# %%
today = time.strftime("%x")
today
# Out:
# '08/09/21'
