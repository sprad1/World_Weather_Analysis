# %%
#pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (7.22.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (5.0.5)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (3.0.17)
# Requirement already satisfied: decorator in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (5.0.6)
# Requirement already satisfied: appnope in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (52.0.0.post20210125)
# Requirement already satisfied: pygments in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (2.8.1)
# Requirement already satisfied: backcall in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: tornado>=4.2 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.3.0)
# Requirement already satisfied: argon2-cffi in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: jinja2 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: nbconvert in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: prometheus-client in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.10.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: pycparser in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: testpath in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: nest-asyncio in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: async-generator in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: webencodings in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/sunisapradhan/opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076097 sha256=bae17f8fe7d3e76099d6d1e255c3a9d0542a4fd7019da972b375be8f3aab63ac
#   Stored in directory: /Users/sunisapradhan/Library/Caches/pip/wheels/30/bd/87/d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 6.5.2 Create Heatmaps for Weather Parameters

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0  Half Moon Bay      US  2021-08-09 21:22:54  37.4636 -122.4286
# 1        1       Coquimbo      CL  2021-08-09 21:25:15 -29.9533  -71.3436
# 2        2         Albany      US  2021-08-09 21:25:16  42.6001  -73.9662
# 3        3       Hermanus      ZA  2021-08-09 21:25:16 -34.4187   19.2345
# 4        4     Bairnsdale      AU  2021-08-09 21:25:17 -37.8333  147.6167
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     96.62        63           1        1.99
# 1     58.73        67          20       11.50
# 2     86.45        60          51        7.47
# 3     49.89        71           3        4.14
# 4     42.08        91           3        1.01

# %%
# Get the data types.
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# Create a Maximum Temperature Heatmap
#
# - First, tell gmaps to use your API key. You only need to configure gmaps to use your API key once.

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %% [markdown]
# Next, create the heatmap for the maximum temperature. The general syntax for creating a heatmap is as follows.

# %%
# # 1. Assign the locations to an array of latitude and longitude pairs.
# locations = [latitude, longitude]
# # 2. Assign the weights variable to some values.
# temperatures = # an array of length equal to the locations array length
# # 3. Assign the figure variable to the gmaps.figure() attribute.
# fig = gmaps.figure()
# # 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)

# # 5. Add the heatmap layer.
# fig.add_layer(heatmap_layer)
# # 6. Call the figure to plot the data.
# fig

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %% [markdown]
# Instead of using the for loop, we can perform a list comprehension within the heatmap_layer() function.
#
# Replace temps with our code for the list comprehension so our heat_layer code looks like the following:
#
# heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
#heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# This map is too large. We will need to make some adjustments to the gmaps.figure() attribute.

# %% [markdown]
# ### Adjust Heatmap Zoom, Intensity, and Point Radius

# %% [markdown]
# First, add the geographic center of Earth in the form of latitude and longitude (30.0° N and 31.0° E). Also, add a zoom level so that only one map of Earth is shown.
#
# When we add a center and zoom level to the gmaps.figure() attribute, it will look like this:

# %% [markdown]
# ### Create a Percent Humidity Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a % Cloudiness Heatmap

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create a Wind Speed Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## 6.5.3 Get Vacation Criteria

# %% [markdown]
# For the app we are creating, we need to prompt the user to enter the minimum and maximum temperature ranges as floating-point decimal numbers to filter the city_data_df DataFrame.
# - Recall that you use the input() statement to prompt a user to enter information. To convert the input to a floating-point decimal number, wrap the input() statement with the float() method, like this: float(input()).

# %%
# Ask the customer to add a min and max temp value
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# Next, filter the maximum temperature column in the city_data_df DataFrame using logical operators to create a new DataFrame with the cities that meet the customer's criteria.
# - Recall that you use the loc[] method on the current DataFrame to create a new DataFrame from a current DataFrame. Inside the brackets, add the conditional filter.

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID        City Country                 Date      Lat       Lng  \
# 2         2      Albany      US  2021-08-09 21:25:16  42.6001  -73.9662
# 6         6      Atuona      PF  2021-08-09 21:25:17  -9.8000 -139.0333
# 9         9     Ransang      PH  2021-08-09 21:25:19   8.9603  117.5828
# 10       10  Coahuayana      MX  2021-08-09 21:25:19  18.7333 -103.6833
# 12       12  Butaritari      KI  2021-08-09 21:25:20   3.0707  172.7902
# 14       14  Sao Filipe      CV  2021-08-09 21:25:20  14.8961  -24.4956
# 15       15   Jaisalmer      IN  2021-08-09 21:25:20  26.9147   70.9181
# 16       16     Da Nang      VN  2021-08-09 21:25:21  16.0678  108.2208
# 19       19        Hilo      US  2021-08-09 21:21:26  19.7297 -155.0900
# 25       25   Jamestown      US  2021-08-09 21:22:01  42.0970  -79.2353
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 2      86.45        60          51        7.47
# 6      78.04        68          14       19.24
# 9      78.85        85         100        4.03
# 10     87.28        78         100        9.82
# 12     82.92        66          16       13.94
# 14     78.55        86          52        8.57
# 15     83.01        61           1       21.72
# 16     86.05        83          20        1.14
# 19     83.25        68           1        8.05
# 25     89.02        49           1        3.00

# %%
# Determine if there are any null values in the preferred_cities_df DataFrame:
# preferred_cities_df.count()
# preferred_cities_df.isnull().sum()
# preferred_cities_df.notnull().sum()

preferred_cities_df.count()
# Out:
# City_ID       191
# City          191
# Country       191
# Date          191
# Lat           191
# Lng           191
# Max Temp      191
# Humidity      191
# Cloudiness    191
# Wind Speed    191
# dtype: int64

# %% [markdown]
# For the above DataFrame, there are 191 cities and no null values

# %% [markdown]
# - Depending on the time of year and the seasons, you might have to adjust the minimum and maximum temperature to get enough cities.
# - It is a good idea to keep the number of cities to fewer than 200 to make it easier to plot the markers on the heatmap.
# - If you have some rows with null values, you'll need to drop them using the dropna() method at the end of your filtering statement when you are creating the new DataFrame.

# %% [markdown]
# ## 6.5.4 Map Vacation Criteria

# %% [markdown]
# Once the customers have filtered the database (DataFrame) based on their temperature preferences, show them a heatmap for the maximum temperature for the filtered cities. In addition, create a marker for each city that will display the name of the city, country code, maximum temperature, and name of a nearby hotel within three miles of the coordinates when the marker is clicked.

# %% [markdown]
# Using the coordinates from the preferred_cities_df DataFrame, find a hotel using our Google Places API and then retrieve that hotel information. Once we retrieve the hotel information, we'll need to store it so we can reference it and add the information to the pop-up marker.

# %% [markdown]
# - Don't add the hotel information to the preferred_cities_df DataFrame because this DataFrame is our filtered DataFrame, and the customer will always filter it for each trip. We'll need to create a new DataFrame specifically for the data needed to create a heatmap and pop-up markers.
#
# - Make a copy of the preferred_cities_df DataFrame and name it hotel_df. For the hotel_df, keep the columns "City," "Country," "Max Temp," "Lat," and "Lng." Add a new column to the hotel_df DataFrame to hold the name of the hotel.
#
# - Add the following code to a new cell and run it to create the hotel_df DataFrame:
# hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
# hotel_df["Hotel Name"] = ""
# hotel_df.head(10)

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp      Lat       Lng Hotel Name
# 2       Albany      US     86.45  42.6001  -73.9662
# 6       Atuona      PF     78.04  -9.8000 -139.0333
# 9      Ransang      PH     78.85   8.9603  117.5828
# 10  Coahuayana      MX     87.28  18.7333 -103.6833
# 12  Butaritari      KI     82.92   3.0707  172.7902
# 14  Sao Filipe      CV     78.55  14.8961  -24.4956
# 15   Jaisalmer      IN     83.01  26.9147   70.9181
# 16     Da Nang      VN     86.05  16.0678  108.2208
# 19        Hilo      US     83.25  19.7297 -155.0900
# 25   Jamestown      US     89.02  42.0970  -79.2353

# %% [markdown]
# Using the latitude and longitude and specific parameters, use the Google Places Nearby Search request to retrieve a hotel and add it to the Hotel Name column.
# ## Retrieve Hotels from a Nearby Search
# The first step for retrieving hotels from a Nearby Search is to set the parameters for the search.

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEArKXytwpZcEKyagcEcVQlB4Fj53NYRvAfqbF0DV0qtp22U9eMu8cWbMbB-VjF0XN__0-BdxUADhZA83SnkioKqP2Y4apuoXisMYFK7xmacjr8sOn8h-Fo92PQM34iobK_li9-UI60tB08GBJV0CBhbYY27HMnngMcM0eFglAjtJbOJdYPZVIRjSMnMRLM4ZnWICjgTft1LhZ74_xVxvoG6gdeMNTj1y2iTneC51hb32ylQ0nEsmYMa21LK1TO4UReNLvFih_zEmddhz_RE90kLqZLXNfEaCd-_aHMsRW_G--zECwm2-yTSwV9LxFYydcE-M8LFUY1aYg-X6qp--pbE-vFELNPnzPY1NPrKCKcp3Zmmn_4s2rJVgin4cjNMv22Uikv-2be7OW6ZiwOgCLeGXPmjcP_6DIx07AIf2j-CO50Cieem2JdE',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291503},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEAzhJCsnzj20d5fupSGP-h_ihKs62JC_LjLfAJZ6GfYrIn4BJbbJ87kEbP90WPQNeUoY8CJO7b5Tn1Vad5sazBLB8WNhzr4z4R53wawYZQhrPYOPrsDBabKQRchfZ9OEiMkuQUftapKYWemcf6i_SNO9KcH8EzgsXbjvkO3LNR8nfYQ',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 285,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.8595495802915,
#       'lng': 2.347780980291502},
#      'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEBeKjfgN0SuHJCVVbbvOUX8njEpxpjTlCidGKJlcWhrZRa7uJ1F7hbeiG4ADjqxPEgPUSe411tMcXn_vz0zvswkx-mDGmPM_rZiBmiw51M7i1WgZ6WjDm6zpiMDuhIf8dtqegxBxHKdWmDplyvHmWaUmaZbsnAiyYWO0l5vlBPWiTQ2',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 572,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617673302915,
#       'lng': 2.348026380291502},
#      'southwest': {'lat': 48.8590693697085, 'lng': 2.345328419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEBZOiDKHLDHdef-0c48jdSwsH6kIVDnlrr41-MqDOVwoz9jv9X1wJUS_vD8SP4e7xcCBSudrFV0uS763ph35zOnU7fUA8C4HRPcrF8dl0SUYX9BC8MQGFotXVBKJhRgWCWQhtw_6_UO23M9L3CHaQaBBxFxgjaZLcJefYmTUhRc4jf4',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 830,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.86205553029149,
#       'lng': 2.347674930291502},
#      'southwest': {'lat': 48.85935756970849, 'lng': 2.344976969708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEDz7yx6fnFrxYxUrh7i4b0sWv_XlEXvLB_xlVt6F_Fszvb_TWUT5aEfiFOqcQrjrrhp2N-ItOR1Z1ebjjJqZpCMDp6qxNpI0murVWdUhPB9JGR9_P75qCj79AYozrJT55imxpy_QfVYX1Cx25p_PZhKDfp6Wq6d41P8y1LpwmqcwqeN',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2184,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86034799999999, 'lng': 2.344054},
#     'viewport': {'northeast': {'lat': 48.8616503302915,
#       'lng': 2.345521080291502},
#      'southwest': {'lat': 48.8589523697085, 'lng': 2.342823119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEBX6HUUMmbbDpUaQCQjGMKFDWbw1iL2C38DhxMBiKqzjtNAv38VADURFrxyuJmPQ5PxLKvpuXd0goFKUiLXGBcQxEFJSRntz4so_Ffwi3GctXosylRMTZcqEx5S4jdBLpIWn3Gg6-N4GWASJhjY6vwzzBwbm_Up6rMvi-k9uyzC2zUG',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 277,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEAF7qwqrJuMYgLovqhtS4SWvuROUc7EKCkRRuVp2pjsuh8TzA53B_MLxWeg2sxw90vBYIZCsiWfYfzpkU-MFbtGmedT7dxhRf6Pf92IwfqisFSDZY3_gax8erN_4vlUSeOE3WGCo5cKrPF28QDf1doqdel-NcyL7Q0vshgjKA_MbUt8',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 682,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8663516, 'lng': 2.360645700000001},
#     'viewport': {'northeast': {'lat': 48.86775293029149,
#       'lng': 2.361904930291503},
#      'southwest': {'lat': 48.8650549697085, 'lng': 2.359206969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uEBCf3UmAY0lZmitNebDDpNxC16IQ-_ofu44fusaLaBua5JveSjn0jP2pCD2obF33DxXs3W_dh_uNcETbhXObpbsBVO_PFjuRD2jLMEKN137MVoq84qnGwq5ZVByeRrXrkwTCraeHbEHH19MR-uPN31-aO3sYwGkcl2vT_GW1xWxVQWY',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 379,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uECF6R2ZyiE_iia_Qoj_A_no4Wvlw8LbjiBKwDHQMdyBSowd_5AI9w8osGmCdlX24BNSrQ4z0qS2u_rme-k60kpuUn24GwOWwdyPxMeB2Kls7obrBNQe7LRtJlqZ8xHql8yLHBX5dyxM8WYXK7yemq8ReLGAiG-sO6Kw4ZmPSbhLwFJC',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 500,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110161480967920528437">stefan kebbekus</a>'],
#      'photo_reference': 'Aap_uEAIUEm7GnHVqhNP4Uni_-RaPBfp6k3BlT2mvz6crcflXz-RkQVdMPLzxz1psSH70TPb1TDyFUwL3NO4JLIg5uGZaWvElTkMZc9kwN_PRfH6MBv4m9rDQkY7vpChTa_fk9THFkrWEHYs6_nHagZ3wsIUqartr-gxrlPFHplFBcS3AGrA',
#      'width': 4000}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 802,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'permanently_closed': True,
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108479076312462330074">Hotels World Online</a>'],
#      'photo_reference': 'Aap_uEAN-iSnQwdCexylKihLErfy75XzHuLeAEDMpcj2373t3EDgDJePcGYtGIh4Ev7LHFv7nT_8uLkJ2jI4KC-JgPhQxgJQXY56RQ1S0cjYEu4fF4hKa1pOtVxJy8DUhV7wM-QtS8PpdoSoRlTPqEqij4T9H62Kog79Gj61VZQ-euYBlCR8',
#      'width': 1024}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEDAw9HBpU-F03WEX6lSe7pgwlaK7cxJR6U9d4PD1WrEZWqt-ir-FMCSLBxj4DwttlGPgLZMVtLbgQd_Bwl7WsbWPHL92ZmwqH5U3Zntq6utVUlXES3hG6Ny3kTCAIi1zHjBl5i6soMkmnMDz1NPxADBmLAnK52wDwzYO0ftkoku4hQv',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 381,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731394302915,
#       'lng': 2.346067130291502},
#      'southwest': {'lat': 48.8704414697085, 'lng': 2.343369169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113098608949799179620">Chrystelle Baudry</a>'],
#      'photo_reference': 'Aap_uEC2V4RSoNutAl6ww_W6k2uCZAEqscb3RsfI3nWlRxRQ7vbu8Vp1nyXzns1ljPQ3A0EBer0J4_nqCKUMu3m49QeVaIFpbRr9vwa4h8pfrtuOYu8bZ-JlJPGRProIDidNi8ECvT1J8DnKeOi8lsf5fnL5RW4HP8W-OxG5srlmjjzMAtUJ',
#      'width': 3840}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.1,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 361,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEAz4WIfjkNrA0TktxqpY_ZxfdcQZh2dexKG7eMSZTIFdagmJb9nRtpsKFAT7E7xWpQYE7pHuL53Si9xudQc7uCb3C5vKTeeLAVDSbYSp-xWgmT_0g3ZSedjrp-_T1QDYxkn3IC3BssQKHyAuEXoJeJJv9wNVlzEfL7O_mUMCHFpST79',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 433,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.864294, 'lng': 2.3307997},
#     'viewport': {'northeast': {'lat': 48.8655772302915,
#       'lng': 2.332153880291502},
#      'southwest': {'lat': 48.8628792697085, 'lng': 2.329455919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uECWpwwoCHIfm5CZn-ruYxeYAMKgm2BpcwIzQ9FzqT_36OSwsauiHEJ5wT4HOB7ISNRSmfCduliuWSRZCPfhpXC7laLo9YMspE3XBk7sAa_6ceWpJfGcVnNKrHupzS6qc-OB1XwucUOTUAlnvR12deJ4T30nRmfW8WtQnXoeRZ8pRg1n',
#      'width': 600}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1074,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uEC93Mwqln3V3XRmErEY-IK5rnN2G8reMLSSuxN7nuC8oHwqbGlL3ZBIIyfehcC9_9RJiP7xXLB_uLMPNIoMvqiol7SK1mCkZqB2cZDzQSwgqrB5oCflJXubX7AWMsz4QCtaAHnLUcXQvtUjlZaMb8bx8bVKtrnG7s_fxp9UtgzP-d7q',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.8,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'Aap_uECWbTGmjAztTyODhielFz3hHkKL9m-q4Z-NodXC9zErklWMUeVJ2eQcMzypjKZ7_8WwS03uZ7oF8GwmjETJeO8yFBtpRtlan4LMb5hGHLSgfxPysxvTDBYrChTKwVOt1weihINoSc3l2YlF-ysb0uzyss-hqQnpqBaM1_xnRSUlDWfJ',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 143,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEAzRa3htRFJO6iZqGCOsRfsGjb01OqhYl1GBKxoq84NJSzmZIQMS9Xwuu5n-IjkG-7I12T13rf99ciVtmcXr4OZM_ZBGvjS2RVn_Qx4D1pCcxBJ7DnTYHn_qpMfLdjdnK_j4WiIvQ7Oy5vPs5by6upCnyqNjQWGprkPqMhfpT49VgxJ',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 326,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#     'viewport': {'northeast': {'lat': 48.8512737302915,
#       'lng': 2.347507380291502},
#      'southwest': {'lat': 48.8485757697085, 'lng': 2.344809419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEA9Df8KuLkHlNOdQA5AGNeASYPY_oH09g9r9BLzS6csQO75C5o2UZSReVIdJsuxXmkaHFZPpX8LxMr_orZQmwm1z5XnqXUD_EtPGbGNpoGkbHQzma5GdaxQAfHCU7CB_0ul1KHs1UZvk712hZKtCghBixNTFotMQFGzqDOc9d3q-eVC',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.6,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 265,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2174,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uEATX_O4UvVfdHGAV_u8ZU7TH3Qm478ux-mE4ms4NBXtR1vsrs_TSws8Yo2UycPmpB6vR6HJ2DpOO0VIrW2CUl0FSKCMS3rAX8vk7nMiypgXkPEf9Kywe0dKtZo3b6alVRw3AVN46snPpGk_46Gs6MNCaYSzznck7koVWyZ-9wMDdIMw',
#      'width': 1739}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 281,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.85313113029149,
#       'lng': 2.346144730291502},
#      'southwest': {'lat': 48.8504331697085, 'lng': 2.343446769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uECLzzYySt_oFKsBLgmOabnS4-t0CkMtLs9AEfil4qt4XAegvVYr7K2HBm1VMN2l7wiUJYejHNpKUybbkx0-uCEivfPv-_YJwjjNnn0y6kGDWY1afMlW1babmO66t1UZvpziuOBSAJUK21zMewVylq8raDsjohdedL1yDSZNesUFEvzF',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %% [markdown]
# ## Iterate Thru hotel_df DataFrame

# %% [markdown]
# We can use the iterrows() function to perform the iteration; however, we need to provide the index and the row in the for loop using this syntax: for index, row in df.iterrows().

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#           City Country  Max Temp      Lat       Lng  \
# 2       Albany      US     86.45  42.6001  -73.9662
# 6       Atuona      PF     78.04  -9.8000 -139.0333
# 9      Ransang      PH     78.85   8.9603  117.5828
# 10  Coahuayana      MX     87.28  18.7333 -103.6833
# 12  Butaritari      KI     82.92   3.0707  172.7902
# 14  Sao Filipe      CV     78.55  14.8961  -24.4956
# 15   Jaisalmer      IN     83.01  26.9147   70.9181
# 16     Da Nang      VN     86.05  16.0678  108.2208
# 19        Hilo      US     83.25  19.7297 -155.0900
# 25   Jamestown      US     89.02  42.0970  -79.2353
#
#                            Hotel Name
# 2
# 6                         Villa Enata
# 9     Black and Crystal Sand Campsite
# 10  El rranchito michuacan de ocampos
# 12                 Isles Sunset Lodge
# 14                      Hotel Xaguate
# 15                         Hotel Fifu
# 16                    Sun River Hotel
# 19                Hilo Hawaiian Hotel
# 25     Hampton Inn & Suites Jamestown

# %% [markdown]
# If you encounter more errors, add them to the except block—like so, (IndexError, NewError)—and continue running your code until there are no errors.

# %% [markdown]
# ## Create a Max Temp Heatmap from a Hotel DataFrame

# %% [markdown]
# Before we add pop-up markers with hotel information, let's create a heatmap using the maximum temperature from our hotel_df DataFrame by reusing the code and changing the DataFrame name.

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Let's add the markers for each city on top of the heatmap

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
